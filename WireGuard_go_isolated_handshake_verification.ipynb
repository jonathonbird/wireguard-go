# %%
# %%bash
# set -euo pipefail
#
# GO_VERSION=1.24.11
# wget -q https://go.dev/dl/go${GO_VERSION}.linux-amd64.tar.gz
# sudo rm -rf /usr/local/go
# sudo tar -C /usr/local -xzf go${GO_VERSION}.linux-amd64.tar.gz
#
# export PATH=/usr/local/go/bin:$PATH
# go version
# Out:
# go version go1.24.11 linux/amd64

# %%
# %%bash
# set -e
#
# export PATH=/usr/local/go/bin:$PATH
#
# # Configure git to use token automatically
# git config --global url."https://${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}@github.com/".insteadOf "https://github.com/"
#
# # Clone the repo
# git clone https://github.com/jonathonbird/wireguard-go.git
# cd wireguard-go
#
# # Switch to your branch
# git checkout handshake-isolated
#
# # Show status
# git status
# git branch
# Out:
# Branch 'handshake-isolated' set up to track remote branch 'handshake-isolated' from 'origin'.
# On branch handshake-isolated
# Your branch is up to date with 'origin/handshake-isolated'.
#
# nothing to commit, working tree clean
# * handshake-isolated
#   master
# Cloning into 'wireguard-go'...
# ...
# Switched to a new branch 'handshake-isolated'

# %%
# %%bash
# set -euo pipefail
# export PATH=/usr/local/go/bin:$PATH
#
# cd wireguard-go
#
# go mod download
#
# # Run everything
# go test ./... -count=1 -v -timeout 120s
# Out:
# === RUN   TestStdNetBindReceiveFuncAfterClose
# --- PASS: TestStdNetBindReceiveFuncAfterClose (0.00s)
# === RUN   Test_coalesceMessages
# === RUN   Test_coalesceMessages/one_message_no_coalesce
# === RUN   Test_coalesceMessages/two_messages_equal_len_coalesce
# === RUN   Test_coalesceMessages/two_messages_unequal_len_coalesce
# === RUN   Test_coalesceMessages/three_messages_second_unequal_len_coalesce
# === RUN   Test_coalesceMessages/three_messages_limited_cap_coalesce
# --- PASS: Test_coalesceMessages (0.00s)
#     --- PASS: Test_coalesceMessages/one_message_no_coalesce (0.00s)
#     --- PASS: Test_coalesceMessages/two_messages_equal_len_coalesce (0.00s)
#     --- PASS: Test_coalesceMessages/two_messages_unequal_len_coalesce (0.00s)
#     --- PASS: Test_coalesceMessages/three_messages_second_unequal_len_coalesce (0.00s)
#     --- PASS: Test_coalesceMessages/three_messages_limited_cap_coalesce (0.00s)
# === RUN   Test_splitCoalescedMessages
# ...
